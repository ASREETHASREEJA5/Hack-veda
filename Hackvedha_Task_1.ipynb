# %% [markdown]
# <a href="https://colab.research.google.com/github/ASREETHASREEJA5/Hack-veda/blob/main/Hackvedha_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Google crawler

# %%
import requests
import pandas as pd
import json
from datetime import date,timedelta

# %%
questions_list = []

keyword = input("Enter a keyword: ")
keyword1 = keyword


#Multiple site search
site_list = ["quora.com","reditt.com"]
for i in site_list:
  keyword = keyword+"site:"+i
  #key file = AIzaSyAfs-KiFaqtlSuYbZyQJWbu79GrRmTldkk
  #cx = 43ac062dd30d24177
  google_url = "https://customsearch.googleapis.com/customsearch/v1/?key=AIzaSyAfs-KiFaqtlSuYbZyQJWbu79GrRmTldkk&cx=43ac062dd30d24177"
  google_url = google_url + "&q="+keyword

  response = requests.get(google_url)

  json_response = json.loads(response.text)
  total_results = int(json_response ["searchInformation"]["totalResults"])
  #get the start index of next page if it exists
  if 'nextPage' in json_response['queries']:
    next_Index = json_response['queries']['nextPage'][0]['startIndex']
  else:
    next_Index = None # Handle the case when there is no next page

  #Loop to all the responses from google
  total_pages = round(total_results/10)
  try:
    #Loop through the responses
    for item in json_response["items"]:
        title = item["title"]
        title = title.replace(" - Quora","")
        questions_list.append(title)

  except Exception as e:
    pass

  #reset the keyword
  keyword = keyword1

questions_dict = {"Questions": questions_list}
df = pd.DataFrame(data = questions_dict)
df
# Out:
# Enter a keyword: Job market trends 2024
#                                             Questions
# 0   Is it wise to major in petroleum engineering i...
# 1   Starting a new blog in 2024 - does it even sta...
# 2   I know the consulting industry is in a slump i...
# 3   Admission / High School Megathread (Fall 2024)...
# 4   I applied for two positions at Amazon. On the ...
# 5   SEO in 2023: Winners, Losers, and Overall Tren...
# 6   What are your predictions for the 2024 Indian ...
# 7     How to Create an Effective SEO Strategy in 2024
# 8              How to get a good website to get a job
# 9   Overview | University of Pittsburgh School of ...
# 10  What do you guys think about the job market co...
# 11                     NHSC Site Reference Guide 2024
# 12  Which path is better: Data Science or Software...
# 13  J. Mack Robinson College of Business | Georgia...
# 14  How bad is the EU job market right now? : r/cs...
# 15                 2024 CACREP Standards Introduction
# ...

# %%
df.to_csv(keyword1+"_questions.csv")

# %% [markdown]
# Mail Automation

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

mail_content = '''Hello,
New notifications regarding "JOB MARKET TRENDS " are released ,
here i am attachinge file of nofications.
Thanks,
Asreetha
'''

#The mail addresses and password
sender_address = 'asreetha86@gmail.com'
sender_pass = 'kzmp othh djmh hkpx'
receiver_address = 'gollaasreethasreeja5@gmail.com'

#Setup the MIME
message = MIMEMultipart()
message['From'] = 'hackvedha intren'
message['To'] = 'User'
#The subject line
message['Subject'] = 'AN IMPORTANT NOTIFICATION'

#The body and the attachments for the mail
message.attach(MIMEText(mail_content, 'plain'))

attach_file_name = '/content/Job market trends 2024_questions.csv'
attach_file = open(attach_file_name, 'rb') # Open the file as binary mode
payload = MIMEBase('application', 'octate-stream')
payload.set_payload((attach_file).read())
encoders.encode_base64(payload) #encode the attachment

#add payload header with filename
payload.add_header('Content-Decomposition', 'attachment', filename=attach_file_name)
message.attach(payload)

#Create SMTP session for sending the mail
session = smtplib.SMTP('smtp.gmail.com', 587) #use gmail with port
session.starttls() #enable security

session.login(sender_address, sender_pass) #login with mail_id and password
text = message.as_string()
session.sendmail(sender_address, receiver_address, text)
session.quit()
print('Mail Sent')
# Out:
# Mail Sent
